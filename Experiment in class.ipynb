# %% [markdown]
# import pandas as pd
#
# file1 = r"C:\Users\Loveline\Documents\DA_materials\rmn_test.csv"
#
# x = pd.read_csv(file1)
# print(x)

# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Loveline\Documents\Loveline's Jupyter Works\Experiment in class.ipynb Cell 2' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Loveline/Documents/Loveline%27s%20Jupyter%20Works/Experiment%20in%20class.ipynb#ch0000001?line=0'>1</a> print(x)
#
# NameError: name 'x' is not defined

# %%
x ["Age"] = [64, 68, 61, 59, 70, 52, 54, 61, 70, 62]
x
# Out:
#    S/N                 Name      Net worth  \
# 0    1        Aliko Dangote  $12.1 Billion
# 1    2         Mike Adenuga   $6.5 Billion
# 2    3     Abdulsamad Rabiu   $5.5 Billion
# 3    4         Femi Otedola  $1.8 Billion
# 4    5   Folorunsho Alakija     $1 Billion
# 5    6          Uzoma Dozie    $1 Billion
# 6    7        Jimoh Ibrahim    $1 Billion
# 7    8       Orji Uzor Kalu    $1 Billion
# 8    9      Jim James Ovia    $980 Million
# 9   10  Hajia Bola Shagaya    $950 Million
#
#                                  Source  Age
# 0                         Manufacturing   64
# 1  Telecommunication and oil production   68
# 2                         Manufacturing   61
# 3                      Power, Oil & Gas   59
# 4           Fashion, Oil  & Real estate   70
# 5                     Banking & Finance   52
# 6                            Investment   54
# 7                           Investment    61
# 8                     Banking & Finance   70
# ...

# %%
x["Gender"] = ["M","M","M","M","F","M","M","M","M","F"]
x
# Out:
#    S/N                 Name      Net worth  \
# 0    1        Aliko Dangote  $12.1 Billion
# 1    2         Mike Adenuga   $6.5 Billion
# 2    3     Abdulsamad Rabiu   $5.5 Billion
# 3    4         Femi Otedola  $1.8 Billion
# 4    5   Folorunsho Alakija     $1 Billion
# 5    6          Uzoma Dozie    $1 Billion
# 6    7        Jimoh Ibrahim    $1 Billion
# 7    8       Orji Uzor Kalu    $1 Billion
# 8    9      Jim James Ovia    $980 Million
# 9   10  Hajia Bola Shagaya    $950 Million
#
#                                  Source  Age Gender
# 0                         Manufacturing   64      M
# 1  Telecommunication and oil production   68      M
# 2                         Manufacturing   61      M
# 3                      Power, Oil & Gas   59      M
# 4           Fashion, Oil  & Real estate   70      F
# 5                     Banking & Finance   52      M
# 6                            Investment   54      M
# 7                           Investment    61      M
# ...

# %%
x["Religion"] = ["Islam","Christianity","Islam","Christianity","Christianity","Christianity","Islam","Christianity","Christianity","Islam"]
x
# Out:
#    S/N                 Name      Net worth  \
# 0    1        Aliko Dangote  $12.1 Billion
# 1    2         Mike Adenuga   $6.5 Billion
# 2    3     Abdulsamad Rabiu   $5.5 Billion
# 3    4         Femi Otedola  $1.8 Billion
# 4    5   Folorunsho Alakija     $1 Billion
# 5    6          Uzoma Dozie    $1 Billion
# 6    7        Jimoh Ibrahim    $1 Billion
# 7    8       Orji Uzor Kalu    $1 Billion
# 8    9      Jim James Ovia    $980 Million
# 9   10  Hajia Bola Shagaya    $950 Million
#
#                                  Source  Age Gender      Religion
# 0                         Manufacturing   64      M         Islam
# 1  Telecommunication and oil production   68      M  Christianity
# 2                         Manufacturing   61      M         Islam
# 3                      Power, Oil & Gas   59      M  Christianity
# 4           Fashion, Oil  & Real estate   70      F  Christianity
# 5                     Banking & Finance   52      M  Christianity
# ...
