# %% [markdown]
# IMPORTATION OF LIBRARIES

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# OFFENSES AGAINST PERSONS

# %%
group2 = pd.read_excel(r"C:\Users\Loveline\Desktop\CRIME STATISTICS 2017.xlsx", sheet_name="Offences Against Persons")
group2.set_index("STATES", inplace=True)
group2.drop("TOTAL",axis=0,inplace=True)
group2
# Out:
#            MURDER  MAN SLAUGHTER  ATTEMPTED MURDER  SUICIDE  \
# STATES
# FCT-ABUJA      91              3                 0        2
# AKWA-IBOM      81              5                78        0
# ANAMBRA        41              0                 0        2
# ABIA           97              6                69        6
# ADAMAWA       114              0                89        4
# BAUCHI         58              0                 1        0
# BENUE          51              3                 6        3
# BORNO         123             48                12       45
# BAYELSA        30              0                19       15
# C/RIVER        87              0                22        0
# DELTA         117              2                21       13
# EBONYI        204             12                13        4
# EDO           187              5                98        3
# ENUGU          40              4                31        0
# ...

# %% [markdown]
# Murder

# %%
group2.groupby("STATES")["MURDER"].max().plot(kind = "barh", figsize = (10,12), color = "red")
plt.minorticks_on()
plt.grid(which="both")
plt.rcParams["font.size"] = 12
plt.title("MURDER CASES IN NIGERIA", fontweight="bold", fontfamily = "algerian",color = "blue")
plt.xlabel("NUMBER OF MURDER CASES", fontfamily = "algerian", color = "b",)
plt.ylabel("STATES", fontfamily = "algerian", color = "b")

plt.savefig("one.png")

# %% [markdown]
# Suicide

# %%
group2.groupby("STATES")["SUICIDE"].max().plot(kind = "barh", figsize = (10,12), color = "darkmagenta")
plt.minorticks_on()
plt.rcParams["font.size"] = 12
plt.grid(which = "major")
plt.title("SUICIDE CASES IN NIGERIA", fontweight="bold",fontfamily = "algerian",color="deeppink")
plt.xlabel("NUMBER OF SUICIDE CASES", color = "deeppink")
plt.ylabel("STATES", color = "deeppink")

plt.savefig('two.png')

# %% [markdown]
# Rape & Indecent Assault

# %%
group2.groupby("STATES")["RAPE & INDECENT ASSAULT"].max().plot(kind = "barh", figsize = (10,12), color = "fuchsia")
plt.minorticks_on()
plt.grid(which="both")
plt.rcParams["font.size"] = 12
plt.title("RAPE & INDECENT ASSAULTS IN NIGERIA", fontweight="bold", fontfamily = "algerian",color = "darkcyan")
plt.xlabel("NUMBER OF RAPE & INDECENT ASSAULT CASES", fontfamily = "algerian", color = "darkcyan")
plt.ylabel("STATES", fontfamily = "algerian", color = "darkcyan")

plt.savefig('three.png')

# %% [markdown]
# Kidnapping

# %%
group2.groupby("STATES")["KIDNAPPING"].max().plot(kind = "barh", figsize = (10,12), color = "darkred")
plt.minorticks_on()
plt.grid(which="both")
plt.rcParams["font.size"] = 12
plt.title("KIDNAP CASES IN NIGERIA", fontweight="bold", fontfamily = "algerian",color = "darkslategrey")
plt.xlabel("NUMBER OF KIDNAP CASES", fontfamily = "algerian", color = "darkslategrey")
plt.ylabel("STATES", fontfamily = "algerian", color = "darkslategrey")

plt.savefig('four.png')

# %% [markdown]
# OFFENSES AGAINST PROPERTY

# %%
group_2 = pd.read_excel(r"C:\Users\Loveline\Desktop\CRIME STATISTICS 2017.xlsx", sheet_name="Offences Against Property")
group_2.set_index("STATES", inplace=True)
group_2.drop("TOTAL",axis=0,inplace=True)
group_2
# Out:
#            ARMED ROBBERY  WOUNDING WITH MENACE  THEFT/STEALING  BURGLARY  \
# STATES
# FCT-ABUJA            384                     0            2586        32
# AKWA-IBOM             47                     6             310        14
# ANAMBRA                6                     0             484        22
# ABIA                  88                     0             570        23
# ADAMAWA               45                     0             825         0
# BAUCHI                57                     0              33         0
# BENUE                 59                     5             811        32
# BORNO                 25                     7             357         4
# BAYELSA              148                     2             266        31
# C/RIVER              112                     4             624        28
# DELTA                 60                    11            1586       156
# EBONYI               370                     7            1272        45
# ...

# %% [markdown]
# Armed Robbery

# %%
group_2.groupby("STATES")["ARMED ROBBERY"].max().plot(kind = "barh", figsize = (10,12), color = "brown")
plt.minorticks_on()
plt.grid(which="both")
plt.rcParams["font.size"] = 12
plt.title("ARMED ROBBERY IN NIGERIA", fontweight="bold", fontfamily = "algerian",color = "darkorchid")
plt.xlabel("NUMBER OF ARMED ROBBERY CASES", fontfamily = "algerian", color = "darkorchid")
plt.ylabel("STATES", fontfamily = "algerian", color = "darkorchid")

plt.savefig('five.png')

# %% [markdown]
# Theft/Stealing

# %%
group_2.groupby("STATES")["THEFT/STEALING"].max().plot(kind = "barh", figsize = (10,12), color = "aqua")
plt.minorticks_on()
plt.grid(which="both")
plt.rcParams["font.size"] = 12
plt.title("THEFT/STEALING CASES IN NIGERIA", fontweight="bold", fontfamily = "algerian",color = "maroon")
plt.xlabel("NUMBER OF THEFT/STEALING CASES", fontfamily = "algerian", color = "maroon")
plt.ylabel("STATES", fontfamily = "algerian", color = "maroon")

plt.savefig('six.png')

# %% [markdown]
# Burglary

# %%
group_2.groupby("STATES")["BURGLARY"].max().plot(kind = "barh", figsize = (10,12), color = "lime")
plt.minorticks_on()
plt.grid(which="both")
plt.rcParams["font.size"] = 12
plt.title("BURGLARY CASES IN NIGERIA", fontweight="bold", fontfamily = "algerian",color = "orange")
plt.xlabel("NUMBER OF BURGLARY CASES", fontfamily = "algerian", color = "orange")
plt.ylabel("STATES", fontfamily = "algerian", color = "orange")

plt.savefig('seven.png')

# %% [markdown]
# False Pretence & Cheating/Fraud

# %%
group_2.groupby("STATES")["FALSE PRETENCE & CHEATING/FRAUD"].max().plot(kind = "barh", figsize = (10,12), color = "deepskyblue")
plt.minorticks_on()
plt.grid(which="both")
plt.rcParams["font.size"] = 12
plt.title("FALSE PRETENCE & CHEATING/FRAUD CASES IN NIGERIA", fontweight="bold", fontfamily = "algerian",color = "midnightblue")
plt.xlabel("NUMBER OF FALSE PRETENCE & CHEATING/FRAUD CASES", fontfamily = "algerian", color = "midnightblue")
plt.ylabel("STATES", fontfamily = "algerian", color = "midnightblue")

plt.savefig('eight.png')

# %% [markdown]
# OFFENSES AGAINST LAWFUL AUTHORITY

# %%
grp2 = pd.read_excel(r"C:\Users\Loveline\Desktop\CRIME STATISTICS 2017.xlsx", sheet_name="Offences Against Lawful Auth.")
grp2.set_index("STATES", inplace=True)
grp2.drop("TOTAL",axis=0,inplace=True)
grp2
# Out:
#            FORGERY OF CURRENCY  COINING OFFENCE  GAMBLING  BREACH OF PEACE  \
# STATES
# FCT-ABUJA                    0                0         0               11
# AKWA-IBOM                    3                0         4              366
# ANAMBRA                      1                2         0              537
# ABIA                         4                0         4              243
# ADAMAWA                      0                0         0               37
# BAUCHI                       4                0         0                0
# BENUE                       11                0         6               64
# BORNO                        2                0         0                1
# BAYELSA                      1                0         0               87
# C/RIVER                      0                0         0               49
# DELTA                        1                2         0              537
# ...

# %% [markdown]
# Forgery Of Currency

# %%
grp2.groupby("STATES")["FORGERY OF CURRENCY"].max().plot(kind = "barh", figsize = (10,12), color = "deeppink")
plt.minorticks_on()
plt.grid(which="both")
plt.rcParams["font.size"] = 12
plt.title("FORGERY OF CURRENCY CASES IN NIGERIA", fontweight="bold", fontfamily = "algerian",color = "indigo")
plt.xlabel("NUMBER OF FORGERY OF CURRENCY CASES", fontfamily = "algerian", color = "indigo")
plt.ylabel("STATES", fontfamily = "algerian", color = "indigo")

plt.savefig('nine.png')

# %% [markdown]
# Breach Of Peace

# %%
grp2.groupby("STATES")["BREACH OF PEACE"].max().plot(kind = "barh", figsize = (10,12), color = "olive")
plt.minorticks_on()
plt.grid(which="both")
plt.rcParams["font.size"] = 12
plt.title("BREACH OF PEACE CASES IN NIGERIA", fontweight="bold", fontfamily = "algerian",color = "darkgreen")
plt.xlabel("NUMBER OF BREACH OF PEACE CASES", fontfamily = "algerian", color = "darkgreen")
plt.ylabel("STATES", fontfamily = "algerian", color = "darkgreen")

plt.savefig('ten.png')

# %% [markdown]
# Bribery & Corruption

# %%
grp2.groupby("STATES")["BRIBERY & CORRUPTION"].max().plot(kind = "barh", figsize = (10,12), color = "mediumvioletred")
plt.minorticks_on()
plt.grid(which="both")
plt.rcParams["font.size"] = 12
plt.title("BRIBERY & CORRUPTION CASES IN NIGERIA", fontweight="bold", fontfamily = "algerian",color = "darkblue")
plt.xlabel("NUMBER OF BRIBERY & CORRUPTION CASES", fontfamily = "algerian", color = "darkblue")
plt.ylabel("STATES", fontfamily = "algerian", color = "darkblue")

plt.savefig('eleven.png')

# %% [markdown]
# Escape From Custody

# %%
grp2.groupby("STATES")["ESCAPE FROM CUSTODY"].max().plot(kind = "barh", figsize = (10,12), color = "teal")
plt.minorticks_on()
plt.grid(which="both")
plt.rcParams["font.size"] = 12
plt.title("ESCAPE FROM CUSTODY CASES IN NIGERIA", fontweight="bold", fontfamily = "algerian",color = "red")
plt.xlabel("NUMBER OF ESCAPE FROM CUSTODY CASES", fontfamily = "algerian", color = "red")
plt.ylabel("STATES", fontfamily = "algerian", color = "red")

plt.savefig('twelve.png')

# %% [markdown]
# SUMMARY

# %%
grp_2 = pd.read_excel(r"C:\Users\Loveline\Desktop\CRIME STATISTICS 2017.xlsx", sheet_name="Summary")
grp_2.set_index("STATES", inplace=True)
grp_2.drop("TOTAL",axis=0,inplace=True)
grp_2
# Out:
#            OFFENCES AGAINST PERSONS  OFFENCES AGAINST PROPERTY  \
# STATES
# FCT-ABUJA                      1183                       4160
# AKWA-IBOM                       702                        593
# ANAMBRA                         127                       1030
# ABIA                           9816                       2320
# ADAMAWA                         811                       1406
# BAUCHI                          196                        186
# BENUE                           431                       1500
# BORNO                           681                        907
# BAYELSA                         612                        840
# C/RIVER                         949                       1158
# DELTA                          3310                       3109
# EBONYI                         1275                       2787
# EDO                             729                        848
# ENUGU                           935                       1111
# ...

# %% [markdown]
# TOTAL NUMBER OF OFFENSES AGAINST PERSONS

# %%
grp_2.groupby("STATES")["OFFENCES AGAINST PERSONS"].max().plot(kind = "barh", figsize = (10,12), color = "coral")
plt.minorticks_on()
plt.grid(which="both")
plt.rcParams["font.size"] = 12
plt.title("TOTAL NUMBER OF OFFENSES AGAINST PERSONS IN NIGERIA", fontweight="bold", fontfamily = "algerian",color = "b")
plt.xlabel("TOTAL NUMBER OF OFFENSES", fontfamily = "algerian", color = "b")
plt.ylabel("STATES", fontfamily = "algerian", color = "b")

plt.savefig('thirteen.png')

# %% [markdown]
# TOTAL NUMBER OF OFFENSES AGAINST PROPERTY

# %%
grp_2.groupby("STATES")["OFFENCES AGAINST PROPERTY"].max().plot(kind = "barh", figsize = (10,12), color = "yellow")
plt.minorticks_on()
plt.grid(which="both")
plt.rcParams["font.size"] = 12
plt.title("TOTAL NUMBER OF OFFENSES AGAINST PROPERTY IN NIGERIA", fontweight="bold", fontfamily = "algerian",color = "forestgreen")
plt.xlabel("TOTAL NUMBER OF OFFENSES", fontfamily = "algerian", color = "forestgreen")
plt.ylabel("STATES", fontfamily = "algerian", color = "forestgreen")

plt.savefig('fourteen.png')

# %% [markdown]
# TOTAL NUMBER OF OFFENSES AGAINST LAWFUL AUTHORITY

# %%
grp_2.groupby("STATES")["OFFENCES AGAINST LAWFUL AUTHORITY"].max().plot(kind = "barh", figsize = (10,12), color = "darkmagenta")
plt.minorticks_on()
plt.grid(which="both")
plt.rcParams["font.size"] = 12
plt.title("TOTAL NUMBER OF OFFENSES AGAINST LAWFUL AUTHORITY IN NIGERIA", fontweight="bold", fontfamily = "algerian",color = "darkorange")
plt.xlabel("TOTAL NUMBER OF OFFENSES", fontfamily = "algerian", color = "darkorange")
plt.ylabel("STATES", fontfamily = "algerian", color = "darkorange")

plt.savefig('fifteen.png')

# %% [markdown]
# OFFENCES AGAINST PERSONS (BY GEOPOLITICAL ZONES IN NIGERIA)

# %% [markdown]
# SouthEast

# %%
expl = [0,0,0,1,0]

SouthEast = grp_2.groupby('STATES')['OFFENCES AGAINST PERSONS'].sum().loc[["ANAMBRA","ENUGU","EBONYI","ABIA","IMO"]]
SouthEast.plot(kind = "pie", figsize = (15,10),
wedgeprops={"edgecolor":"k", "linewidth":3.22}, shadow=True, autopct="%1.2f%%", frame=True,explode=expl)
plt.title("RATE OF OFFENSES AGAINST PERSONS BY GEOPOLITICAL ZONES IN NIGERIA (South East)", fontfamily="algerian", fontweight = "bold", loc="center")
plt.legend(loc=(0,-0.3), title="key:")

plt.savefig("sixteen.png")

# %% [markdown]
# SouthWest

# %%
expl = [0,1,0,0,0,0]

SouthWest = grp_2.groupby('STATES')['OFFENCES AGAINST PERSONS'].sum().loc[["EKITI","LAGOS","OGUN","ONDO","OSUN","OYO"]]
SouthWest.plot(kind = "pie", figsize = (15,10),
wedgeprops={"edgecolor":"k", "linewidth":3.22}, shadow=True, autopct="%1.2f%%",explode=expl, frame=True,)
plt.title("RATE OF OFFENSES AGAINST PERSONS BY GEOPOLITICAL ZONES IN NIGERIA (South West)", fontfamily="algerian", fontweight = "bold", loc="right")
plt.legend(loc=(0,-0.3), title="key:")

plt.savefig("seventeen.png")

# %% [markdown]
# SouthSouth

# %%
expl = [0,0,0,1,0,0]

SouthSouth = grp_2.groupby('STATES')['OFFENCES AGAINST PROPERTY'].sum().loc[["AKWA-IBOM","BAYELSA","C/RIVER","DELTA","EDO","RIVERS"]]
SouthSouth.plot(kind = "pie", figsize = (15,10),
wedgeprops={"edgecolor":"k", "linewidth":3.22}, shadow=True, autopct="%1.2f%%", frame=True,explode=expl)
plt.title("RATE OF OFFENSES AGAINST PERSONS BY GEOPOLITICAL ZONES IN NIGERIA (South South)", fontfamily="algerian", fontweight = "bold", loc="center")
plt.legend(loc=(0,-0.3), title="key:")

plt.savefig("eighteen.png")

# %% [markdown]
# NorthWest

# %%
expl = [0,0,0,1,0,0,0]

NorthWest = grp_2.groupby('STATES')['OFFENCES AGAINST PERSONS'].sum().loc[["JIGAWA","KADUNA","KANO","KATSINA","KEBBI","SOKOTO","ZAMFARA"]]
NorthWest.plot(kind = "pie", figsize = (15,10),
wedgeprops={"edgecolor":"k", "linewidth":3.22}, shadow=True, autopct="%1.2f%%", frame=True,explode=expl)
plt.title("RATE OF OFFENSES AGAINST PERSONS BY GEOPOLITICAL ZONES IN NIGERIA (North West)", fontfamily="algerian", fontweight = "bold", loc="center")
plt.legend(loc=(0,-0.2), title="key:")

plt.savefig("nineteen.png")

# %% [markdown]
# NorthEast

# %%
expl = [0,0,0,1,0,0,0]

NorthEast = grp_2.groupby('STATES')['OFFENCES AGAINST PERSONS'].sum().loc[["JIGAWA","KADUNA","KANO","KATSINA","KEBBI","SOKOTO","ZAMFARA"]]
NorthEast.plot(kind = "pie", figsize = (15,10),
wedgeprops={"edgecolor":"k", "linewidth":3.22}, shadow=True, autopct="%1.2f%%", frame=True,explode=expl)
plt.title("RATE OF OFFENSES AGAINST PERSONS BY GEOPOLITICAL ZONES IN NIGERIA (North East)", fontfamily="algerian", fontweight = "bold", loc="center")
plt.legend(loc=(0,-0.2), title="key:")

plt.savefig("twenty.png")

# %% [markdown]
# NorthCentral

# %%
expl = [0,0,0,0,0,0,1]

NorthCentral = grp_2.groupby('STATES')['OFFENCES AGAINST PERSONS'].sum().loc[["BENUE","KOGI","KWARA","NASARAWA","NIGER","PLATEAU","FCT-ABUJA"]]
NorthCentral.plot(kind = "pie", figsize = (15,10),
wedgeprops={"edgecolor":"k", "linewidth":3.22}, shadow=True, autopct="%1.2f%%", frame=True,explode=expl)
plt.title("RATE OF OFFENSES AGAINST PERSONS BY GEOPOLITICAL ZONES IN NIGERIA (North Central)", fontfamily="algerian", fontweight = "bold", loc="center")
plt.legend(loc=(1,-0.2), title="key:")

plt.savefig("twentyone.png")

# %% [markdown]
# OFFENCES AGAINST PROPERTY (BY GEOPOLITICAL ZONES IN NIGERIA)

# %% [markdown]
# SouthEast

# %%
expl = [0,0,0,1,0]

SouthEast1 = grp_2.groupby('STATES')['OFFENCES AGAINST PROPERTY'].sum().loc[["ANAMBRA","ENUGU","EBONYI","ABIA","IMO"]]
SouthEast1.plot(kind = "pie", figsize = (15,10),
wedgeprops={"edgecolor":"k", "linewidth":3.22}, shadow=True, autopct="%1.2f%%", frame=True,explode=expl)
plt.title("RATE OF OFFENSES AGAINST PROPERTY BY GEOPOLITICAL ZONES IN NIGERIA (South East)", fontfamily="algerian", fontweight = "bold", loc="center")
plt.legend(loc=(0,-0.3), title="key:")

plt.savefig("twentytwo.png")

# %% [markdown]
# SouthWest

# %%
expl = [0,1,0,0,0,0]

SouthWest1 = grp_2.groupby('STATES')['OFFENCES AGAINST PROPERTY'].sum().loc[["EKITI","LAGOS","OGUN","ONDO","OSUN","OYO"]]
SouthWest1.plot(kind = "pie", figsize = (15,10),
wedgeprops={"edgecolor":"k", "linewidth":3.22}, shadow=True, autopct="%1.2f%%",explode=expl, frame=True,)
plt.title("RATE OF OFFENSES AGAINST PROPERTY BY GEOPOLITICAL ZONES IN NIGERIA (South West)", fontfamily="algerian", fontweight = "bold", loc="right")
plt.legend(loc=(0,-0.3), title="key:")

plt.savefig("twentythree.png")

# %% [markdown]
# SouthSouth

# %%
expl = [0,0,0,1,0,0]

SouthSouth1 = grp_2.groupby('STATES')['OFFENCES AGAINST PROPERTY'].sum().loc[["AKWA-IBOM","BAYELSA","C/RIVER","DELTA","EDO","RIVERS"]]
SouthSouth1.plot(kind = "pie", figsize = (15,10),
wedgeprops={"edgecolor":"k", "linewidth":3.22}, shadow=True, autopct="%1.2f%%", frame=True,explode=expl)
plt.title("RATE OF OFFENSES AGAINST PROPERTY BY GEOPOLITICAL ZONES IN NIGERIA (South South)", fontfamily="algerian", fontweight = "bold", loc="center")
plt.legend(loc=(0,-0.3), title="key:")

plt.savefig("twentyfour.png")

# %% [markdown]
# NorthWest

# %%
expl = [0,0,0,1,0,0,0]

NorthWest1 = grp_2.groupby('STATES')['OFFENCES AGAINST PROPERTY'].sum().loc[["JIGAWA","KADUNA","KANO","KATSINA","KEBBI","SOKOTO","ZAMFARA"]]
NorthWest1.plot(kind = "pie", figsize = (15,10),
wedgeprops={"edgecolor":"k", "linewidth":3.22}, shadow=True, autopct="%1.2f%%", frame=True,explode=expl)
plt.title("RATE OF OFFENSES AGAINST PROPERTY BY GEOPOLITICAL ZONES IN NIGERIA (North West)", fontfamily="algerian", fontweight = "bold", loc="center")
plt.legend(loc=(0,-0.2), title="key:")

plt.savefig("twentyfive.png")

# %% [markdown]
# NorthEast

# %%
expl = [0,0,0,1,0,0,0]

NorthEast1 = grp_2.groupby('STATES')['OFFENCES AGAINST PROPERTY'].sum().loc[["JIGAWA","KADUNA","KANO","KATSINA","KEBBI","SOKOTO","ZAMFARA"]]
NorthEast1.plot(kind = "pie", figsize = (15,10),
wedgeprops={"edgecolor":"k", "linewidth":3.22}, shadow=True, autopct="%1.2f%%", frame=True,explode=expl)
plt.title("RATE OF OFFENSES AGAINST PROPERTY BY GEOPOLITICAL ZONES IN NIGERIA (North East)", fontfamily="algerian", fontweight = "bold", loc="center")
plt.legend(loc=(0,-0.2), title="key:")

# %% [markdown]
# NorthCentral

# %%
expl = [0,0,0,0,0,0,1]

NorthCentral1 = grp_2.groupby('STATES')['OFFENCES AGAINST PROPERTY'].sum().loc[["BENUE","KOGI","KWARA","NASARAWA","NIGER","PLATEAU","FCT-ABUJA"]]
NorthCentral1.plot(kind = "pie", figsize = (15,10),
wedgeprops={"edgecolor":"k", "linewidth":3.22}, shadow=True, autopct="%1.2f%%", frame=True,explode=expl)
plt.title("RATE OF OFFENSES AGAINST PROPERTY BY GEOPOLITICAL ZONES IN NIGERIA (North Central)", fontfamily="algerian", fontweight = "bold", loc="center")
plt.legend(loc=(1,-0.2), title="key:")

plt.savefig("twentysix.png")

# %% [markdown]
# OFFENCES AGAINST LAWFUL AUTHORITY (BY GEOPOLITICAL ZONES IN NIGERIA)

# %% [markdown]
# SouthEast

# %%
expl = [0,0,0,1,0]

SouthEast2 = grp_2.groupby('STATES')['OFFENCES AGAINST LAWFUL AUTHORITY'].sum().loc[["ANAMBRA","ENUGU","EBONYI","ABIA","IMO"]]
SouthEast2.plot(kind = "pie", figsize = (15,10),
wedgeprops={"edgecolor":"k", "linewidth":3.22}, shadow=True, autopct="%1.2f%%", frame=True,explode=expl)
plt.title("RATE OF OFFENSES AGAINST LAWFUL AUTHORITY BY GEOPOLITICAL ZONES IN NIGERIA (South East)", fontfamily="algerian", fontweight = "bold", loc="center")
plt.legend(loc=(0,-0.3), title="key:")

plt.savefig("twentyseven.png")

# %% [markdown]
# SouthWest

# %%
expl = [0,1,0,0,0,0]

SouthWest2 = grp_2.groupby('STATES')['OFFENCES AGAINST LAWFUL AUTHORITY'].sum().loc[["EKITI","LAGOS","OGUN","ONDO","OSUN","OYO"]]
SouthWest2.plot(kind = "pie", figsize = (15,10),
wedgeprops={"edgecolor":"k", "linewidth":3.22}, shadow=True, autopct="%1.2f%%",explode=expl, frame=True,)
plt.title("RATE OF OFFENSES AGAINST LAWFUL AUTHORITY BY GEOPOLITICAL ZONES IN NIGERIA (South West)", fontfamily="algerian", fontweight = "bold", loc="right")
plt.legend(loc=(0,-0.3), title="key:")

plt.savefig("twentyeight.png")

# %% [markdown]
# SouthSouth

# %%
expl = [0,0,0,1,0,0]

SouthSouth2 = grp_2.groupby('STATES')['OFFENCES AGAINST LAWFUL AUTHORITY'].sum().loc[["AKWA-IBOM","BAYELSA","C/RIVER","DELTA","EDO","RIVERS"]]
SouthSouth2.plot(kind = "pie", figsize = (15,10),
wedgeprops={"edgecolor":"k", "linewidth":3.22}, shadow=True, autopct="%1.2f%%", frame=True,explode=expl)
plt.title("RATE OF OFFENSES AGAINST LAWFUL AUTHORITY BY GEOPOLITICAL ZONES IN NIGERIA (South South)", fontfamily="algerian", fontweight = "bold", loc="center")
plt.legend(loc=(0,-0.3), title="key:")

plt.savefig("twentynine.png")

# %% [markdown]
# NorthWest

# %%
expl = [0,0,0,1,0,0,0]

NorthWest2 = grp_2.groupby('STATES')['OFFENCES AGAINST LAWFUL AUTHORITY'].sum().loc[["JIGAWA","KADUNA","KANO","KATSINA","KEBBI","SOKOTO","ZAMFARA"]]
NorthWest2.plot(kind = "pie", figsize = (15,10),
wedgeprops={"edgecolor":"k", "linewidth":3.22}, shadow=True, autopct="%1.2f%%", frame=True,explode=expl)
plt.title("RATE OF OFFENSES AGAINST LAWFUL AUTHORITY BY GEOPOLITICAL ZONES IN NIGERIA (North West)", fontfamily="algerian", fontweight = "bold", loc="center")
plt.legend(loc=(0,-0.2), title="key:")

plt.savefig("thirty.png")

# %% [markdown]
# NorthEast

# %%
expl = [0,0,0,1,0,0,0]

NorthEast2 = grp_2.groupby('STATES')['OFFENCES AGAINST LAWFUL AUTHORITY'].sum().loc[["JIGAWA","KADUNA","KANO","KATSINA","KEBBI","SOKOTO","ZAMFARA"]]
NorthEast2.plot(kind = "pie", figsize = (15,10),
wedgeprops={"edgecolor":"k", "linewidth":3.22}, shadow=True, autopct="%1.2f%%", frame=True,explode=expl)
plt.title("RATE OF OFFENSES AGAINST LAWFUL AUTHORITY BY GEOPOLITICAL ZONES IN NIGERIA (North East)", fontfamily="algerian", fontweight = "bold", loc="center")
plt.legend(loc=(0,-0.2), title="key:")
plt.savefig("ROF NE.png")


plt.savefig("thirtyone.png")

# %% [markdown]
# NorthCentral

# %%
expl = [0,0,0,0,0,0,1]

NorthCentral2 = grp_2.groupby('STATES')['OFFENCES AGAINST LAWFUL AUTHORITY'].sum().loc[["BENUE","KOGI","KWARA","NASARAWA","NIGER","PLATEAU","FCT-ABUJA"]]
NorthCentral2.plot(kind = "pie", figsize = (15,10),
wedgeprops={"edgecolor":"k", "linewidth":3.22}, shadow=True, autopct="%1.2f%%", frame=True,explode=expl)
plt.title("RATE OF OFFENSES AGAINST LAWFUL AUTHORITY BY GEOPOLITICAL ZONES IN NIGERIA (North Central)", fontfamily="algerian", fontweight = "bold", loc="center")
plt.legend(loc=(1,-0.2), title="key:")


plt.savefig("thirtytwo.png")
